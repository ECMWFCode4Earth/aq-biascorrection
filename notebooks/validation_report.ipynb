# %%
import glob
import pandas as pd
import numpy as np
from src.constants import ROOT_DIR
from src.data.utils import Location
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
# Out:
# Project directory (ROOT_DIR): '/home/pereza/git/esowc/aq-biascorrection'

# %% [markdown]
# This notebook is used to get information about the predictions validations CSVs generated.

# %%
variable = str(input('Let me know the variable to report the results (no2, o3, pm25): '))
dir_to_tables = ROOT_DIR / 'reports' / 'tables' / variable / 'results' / 'SetOfRuns'
# Out:
# Let me know the variable to report the results (no2, o3, pm25): no2

# %%
dir_to_tables
# Out:
# PosixPath('/home/pereza/git/esowc/aq-biascorrection/reports/tables/no2/results/SetOfRuns')

# %%
csv_files = glob.glob(str(dir_to_tables / "*.csv"))
train_files = [file for file in csv_files if 'train' in file]
test_files = [file for file in csv_files if 'test' in file]
train_files.sort()
test_files.sort()

# %%
train_files[:1]
# Out:
# ['/home/pereza/git/esowc/aq-biascorrection/reports/tables/no2/results/SetOfRuns/train_metrics-for-setofruns_at001_vienna_austria.csv']

# %%
test_files[:1]
# Out:
# ['/home/pereza/git/esowc/aq-biascorrection/reports/tables/no2/results/SetOfRuns/test_metrics-for-setofruns_at001_vienna_austria.csv']

# %%
point_values_list = []
for train_file, test_file in zip(train_files, test_files):
    # Get the city and country of the station
    station_id = train_file.split('.csv')[0].split('_')[-3].upper()
    station_obj = Location.get_location_by_id(station_id)
    
    # Read the train and test data
    train_data = pd.read_csv(train_file, index_col=[0, 1])
    test_data = pd.read_csv(test_file, index_col=[0,1])
    
    # Study the mean value of all runs
    train_data_mean = train_data.loc[('Mean'), :].to_dict()
    test_data_mean = test_data.loc[('Mean'), :].to_dict()
    
    point_values_list.append(
        {
            "station": station_obj,
            "values_train": train_data_mean,
            "len_train": len(train_data) // 2 -1,
            "values_test": test_data_mean,
            "len_test": len(test_data) // 2 -1
        }
    )

# %%
for station in point_values_list:
    print(f"Checking the metrics for {station['station'].city} ({station['station'].country})")
    for metric, values in station['values_train'].items():
        if metric in ['NMAE', 'RMSE', 'De-Biased NMAE']:
            percentage = 100 * (values['CAMS Forecast + Correction'] - 
                                values['CAMS Forecast']) / values['CAMS Forecast']
        elif :
            percentage = 100 * (np.abs(values['CAMS Forecast + Correction']) - 
                                np.abs(values['CAMS Forecast'])) / np.abs(values['CAMS Forecast'])
        print(f"{metric}: {percentage} %")
    print('\n')
# Out:
# Checking the train metrics for Vienna (Austria) using 347 runs
# NMAE: from 0.556 to 0.508
# BIAS: from 1.021 to 5.313
# RMSE: from 13.056 to 11.691
# De-Biased NMAE: from 0.489 to 0.39
# Pearson Correlation: from 0.4 to 0.594
#
#
# Checking the train metrics for Salzburg (Austria) using 363 runs
# NMAE: from 0.624 to 0.362
# BIAS: from -9.472 to -1.432
# RMSE: from 15.113 to 9.296
# De-Biased NMAE: from 0.431 to 0.304
# Pearson Correlation: from 0.103 to 0.473
#
#
# Checking the train metrics for Adelaide (Australia) using 452 runs
# NMAE: from 0.657 to 0.539
# BIAS: from -7.199 to -2.705
# RMSE: from 13.959 to 11.121
# De-Biased NMAE: from 0.557 to 0.474
# Pearson Correlation: from 0.086 to 0.376
#
#
# Checking the train metrics for Sydney (Australia) using 623 runs
# NMAE: from 1.919 to 1.332
# BIAS: from 9.132 to 3.312
# RMSE: from 19.715 to 15.741
# De-Biased NMAE: from 1.168 to 0.901
# Pearson Correlation: from 0.343 to 0.43
#
#
# Checking the train metrics for Melbourne (Australia) using 535 runs
# NMAE: from 0.515 to 0.525
# BIAS: from -0.111 to 1.49
# RMSE: from 9.523 to 8.927
# De-Biased NMAE: from 0.442 to 0.418
# Pearson Correlation: from 0.331 to 0.465
#
#
# Checking the train metrics for Canberra (Australia) using 119 runs
# NMAE: from 0.68 to 0.719
# BIAS: from -1.3 to -0.267
# RMSE: from 6.839 to 7.043
# De-Biased NMAE: from 0.53 to 0.636
# Pearson Correlation: from 0.415 to 0.251
#
#
# Checking the train metrics for Dhaka (Bangladesh) using 76 runs
# NMAE: from 5.758 to 1.935
# BIAS: from 69.035 to 20.547
# RMSE: from 77.212 to 27.203
# De-Biased NMAE: from 2.473 to 1.014
# Pearson Correlation: from 0.633 to 0.398
#
#
# Checking the train metrics for Brussels (Belgium) using 1 runs
# NMAE: from 0.55 to 0.593
# BIAS: from 12.935 to 16.685
# RMSE: from 23.842 to 24.108
# De-Biased NMAE: from 0.582 to 0.502
# Pearson Correlation: from -0.168 to 0.039
#
#
# Checking the train metrics for Sofia (Bulgaria) using 358 runs
# NMAE: from 0.703 to 0.367
# BIAS: from -16.357 to -2.026
# RMSE: from 19.675 to 10.659
# De-Biased NMAE: from 0.355 to 0.296
# Pearson Correlation: from 0.173 to 0.518
#
#
# Checking the train metrics for São Paulo (Brazil) using 116 runs
# NMAE: from 1.0 to 0.364
# BIAS: from -28.801 to -4.578
# RMSE: from 30.36 to 12.664
# De-Biased NMAE: from 0.273 to 0.268
# Pearson Correlation: from -0.16 to 0.245
#
#
# Checking the train metrics for Montreal (Canada) using 339 runs
# NMAE: from 0.76 to 0.616
# BIAS: from -10.791 to -0.506
# RMSE: from 13.181 to 8.753
# De-Biased NMAE: from 0.412 to 0.403
# Pearson Correlation: from -0.188 to 0.18
#
#
# Checking the train metrics for Vancouver (Canada) using 541 runs
# NMAE: from 0.897 to 0.952
# BIAS: from -3.888 to 1.335
# RMSE: from 11.817 to 10.671
# De-Biased NMAE: from 0.681 to 0.632
# Pearson Correlation: from -0.183 to -0.015
#
#
# Checking the train metrics for Zurich (Switzerland) using 455 runs
# NMAE: from 0.605 to 0.5
# BIAS: from -2.935 to 4.058
# RMSE: from 16.128 to 13.784
# De-Biased NMAE: from 0.491 to 0.375
# Pearson Correlation: from 0.222 to 0.44
#
#
# Checking the train metrics for Geneva (Switzerland) using 683 runs
# NMAE: from 0.591 to 0.562
# BIAS: from -3.766 to 1.317
# RMSE: from 10.816 to 9.23
# De-Biased NMAE: from 0.469 to 0.409
# Pearson Correlation: from 0.314 to 0.454
#
#
# Checking the train metrics for Santiago (Chile) using 644 runs
# NMAE: from 0.999 to 0.365
# BIAS: from -33.982 to -3.661
# RMSE: from 36.555 to 14.497
# De-Biased NMAE: from 0.32 to 0.27
# Pearson Correlation: from -0.338 to 0.562
#
#
# Checking the train metrics for Shanghai (China) using 916 runs
# NMAE: from 1.732 to 0.694
# BIAS: from 57.564 to 15.128
# RMSE: from 62.915 to 28.451
# De-Biased NMAE: from 0.597 to 0.479
# Pearson Correlation: from 0.451 to 0.367
#
#
# Checking the train metrics for Chongqing (China) using 902 runs
# NMAE: from 0.78 to 0.466
# BIAS: from 26.606 to 5.364
# RMSE: from 39.672 to 26.434
# De-Biased NMAE: from 0.438 to 0.365
# Pearson Correlation: from 0.438 to 0.323
#
#
# Checking the train metrics for Beijing (China) using 905 runs
# NMAE: from 2.724 to 1.118
# BIAS: from 81.736 to 25.149
# RMSE: from 90.091 to 42.615
# De-Biased NMAE: from 1.051 to 0.791
# Pearson Correlation: from 0.354 to 0.374
#
#
# Checking the train metrics for Shenyang (China) using 912 runs
# NMAE: from 1.004 to 0.577
# BIAS: from 27.93 to 3.418
# RMSE: from 38.307 to 22.955
# De-Biased NMAE: from 0.629 to 0.464
# Pearson Correlation: from 0.409 to 0.409
#
#
# Checking the train metrics for Bogotá (Colombia) using 104 runs
# NMAE: from 0.995 to 0.327
# BIAS: from -33.737 to -2.97
# RMSE: from 35.389 to 12.965
# De-Biased NMAE: from 0.254 to 0.242
# Pearson Correlation: from -0.139 to 0.285
#
#
# Checking the train metrics for Prague (Czechia) using 548 runs
# NMAE: from 0.459 to 0.353
# BIAS: from -5.073 to 1.378
# RMSE: from 14.337 to 11.463
# De-Biased NMAE: from 0.332 to 0.278
# Pearson Correlation: from 0.478 to 0.596
#
#
# Checking the train metrics for Copenhagen (Denmark) using 563 runs
# NMAE: from 0.673 to 0.632
# BIAS: from -10.633 to -0.609
# RMSE: from 14.117 to 9.496
# De-Biased NMAE: from 0.37 to 0.4
# Pearson Correlation: from 0.348 to 0.53
#
#
# Checking the train metrics for Madrid (Spain) using 263 runs
# NMAE: from 0.932 to 0.451
# BIAS: from -38.162 to -8.067
# RMSE: from 40.777 to 20.744
# De-Biased NMAE: from 0.306 to 0.3
# Pearson Correlation: from 0.345 to 0.315
#
#
# Checking the train metrics for Barcelona (Spain) using 291 runs
# NMAE: from 0.571 to 0.408
# BIAS: from -16.956 to -0.781
# RMSE: from 22.18 to 15.226
# De-Biased NMAE: from 0.302 to 0.29
# Pearson Correlation: from 0.371 to 0.413
#
#
# Checking the train metrics for Helsinki (Finland) using 818 runs
# NMAE: from 0.556 to 0.505
# BIAS: from -9.078 to 0.018
# RMSE: from 14.207 to 11.093
# De-Biased NMAE: from 0.397 to 0.361
# Pearson Correlation: from 0.395 to 0.558
#
#
# Checking the train metrics for Paris (France) using 553 runs
# NMAE: from 0.5 to 0.381
# BIAS: from -10.278 to -0.114
# RMSE: from 19.23 to 14.498
# De-Biased NMAE: from 0.354 to 0.294
# Pearson Correlation: from 0.354 to 0.509
#
#
# Checking the train metrics for London (United Kingdom) using 664 runs
# NMAE: from 0.414 to 0.367
# BIAS: from -6.519 to 2.716
# RMSE: from 15.123 to 12.741
# De-Biased NMAE: from 0.312 to 0.271
# Pearson Correlation: from 0.477 to 0.575
#
#
# Checking the train metrics for Glasgow (United Kingdom) using 578 runs
# NMAE: from 0.872 to 0.647
# BIAS: from -20.569 to -3.806
# RMSE: from 23.424 to 13.699
# De-Biased NMAE: from 0.388 to 0.372
# Pearson Correlation: from 0.041 to 0.417
#
#
# Checking the train metrics for Belfast (United Kingdom) using 609 runs
# NMAE: from 0.787 to 0.607
# BIAS: from -16.309 to -5.925
# RMSE: from 20.984 to 15.004
# De-Biased NMAE: from 0.459 to 0.42
# Pearson Correlation: from 0.084 to 0.347
#
#
# Checking the train metrics for Cayenne (French Guiana) using 498 runs
# NMAE: from 0.944 to 1.061
# BIAS: from -2.62 to 0.425
# RMSE: from 3.692 to 2.978
# De-Biased NMAE: from 0.673 to 0.743
# Pearson Correlation: from -0.059 to 0.327
#
#
# Checking the train metrics for Athens (Greece) using 376 runs
# NMAE: from 0.692 to 0.276
# BIAS: from -29.682 to -2.102
# RMSE: from 33.922 to 14.383
# De-Biased NMAE: from 0.288 to 0.218
# Pearson Correlation: from 0.088 to 0.44
#
#
# Checking the train metrics for Hong Kong (Hong Kong) using 477 runs
# NMAE: from 0.449 to 0.392
# BIAS: from 17.634 to 12.956
# RMSE: from 37.232 to 32.86
# De-Biased NMAE: from 0.323 to 0.29
# Pearson Correlation: from 0.643 to 0.664
#
#
# Checking the train metrics for Zagreb (Croatia) using 571 runs
# NMAE: from 0.757 to 0.672
# BIAS: from -9.541 to -2.133
# RMSE: from 19.737 to 15.741
# De-Biased NMAE: from 0.508 to 0.468
# Pearson Correlation: from 0.35 to 0.47
#
#
# Checking the train metrics for Budapest (Hungary) using 529 runs
# NMAE: from 0.583 to 0.341
# BIAS: from -17.438 to -2.628
# RMSE: from 21.987 to 13.381
# De-Biased NMAE: from 0.298 to 0.271
# Pearson Correlation: from 0.427 to 0.543
#
#
# Checking the train metrics for Dublin (Ireland) using 565 runs
# NMAE: from 0.705 to 0.946
# BIAS: from -4.554 to 4.171
# RMSE: from 11.334 to 11.207
# De-Biased NMAE: from 0.569 to 0.521
# Pearson Correlation: from 0.229 to 0.365
#
#
# Checking the train metrics for New Delhi (India) using 540 runs
# NMAE: from 1.31 to 0.717
# BIAS: from 36.598 to 9.631
# RMSE: from 50.801 to 31.272
# De-Biased NMAE: from 0.811 to 0.578
# Pearson Correlation: from 0.367 to 0.321
#
#
# Checking the train metrics for Kolkata (India) using 617 runs
# NMAE: from 1.016 to 0.597
# BIAS: from 26.408 to 5.762
# RMSE: from 40.449 to 24.167
# De-Biased NMAE: from 0.733 to 0.476
# Pearson Correlation: from 0.586 to 0.466

# %%
for station in point_values_list:
    print(f" - Checking the train metrics for " \
          f"{station['station'].city} ({station['station'].country}) using {station['len_train']} runs:")
    for metric, values in station['values_train'].items():
        cams = round(values['CAMS Forecast'], 3)
        prediction = round(values['CAMS Forecast + Correction'], 3)
        if metric in ['NMAE', 'RMSE', 'De-Biased NMAE']:
            percentage = round(100 * (prediction - cams) / cams, 2)
        elif metric == 'BIAS':
            percentage = round(100 * (abs(prediction) - abs(cams)) / abs(cams), 2)
        elif metric == 'Pearson Correlation':
            percentage = round(100 * (prediction - cams) / abs(cams), 2)
        print(f"{metric}: from {cams} to {prediction} ({percentage} %)")
        
    print(f" - Checking the test metrics for " \
          f"{station['station'].city} ({station['station'].country}) using {station['len_test']} runs:")
    for metric, values in station['values_test'].items():
        cams = round(values['CAMS Forecast'], 3)
        prediction = round(values['CAMS Forecast + Correction'], 3)
        if metric in ['NMAE', 'RMSE', 'De-Biased NMAE']:
            percentage = round(100 * (prediction - cams) / cams, 2)
        elif metric == 'BIAS':
            percentage = round(100 * (abs(prediction) - abs(cams)) / abs(cams), 2)
        elif metric == 'Pearson Correlation':
            percentage = round(100 * (prediction - cams) / abs(cams), 2)
        print(f"{metric}: from {cams} to {prediction} ({percentage} %)")
    print('\n')
# Out:
#  - Checking the train metrics for Vienna (Austria) using 347 runs:
# NMAE: from 0.556 to 0.508 (-8.63 %)
# BIAS: from 1.021 to 5.313 (420.37 %)
# RMSE: from 13.056 to 11.691 (-10.45 %)
# De-Biased NMAE: from 0.489 to 0.39 (-20.25 %)
# Pearson Correlation: from 0.4 to 0.594 (48.5 %)
#  - Checking the test metrics for Vienna (Austria) using 87 runs:
# NMAE: from 0.578 to 0.548 (-5.19 %)
# BIAS: from 1.613 to 5.935 (267.95 %)
# RMSE: from 13.495 to 12.661 (-6.18 %)
# De-Biased NMAE: from 0.504 to 0.411 (-18.45 %)
# Pearson Correlation: from 0.407 to 0.579 (42.26 %)
#
#
#  - Checking the train metrics for Salzburg (Austria) using 363 runs:
# NMAE: from 0.624 to 0.362 (-41.99 %)
# BIAS: from -9.472 to -1.432 (-84.88 %)
# RMSE: from 15.113 to 9.296 (-38.49 %)
# De-Biased NMAE: from 0.431 to 0.304 (-29.47 %)
# Pearson Correlation: from 0.103 to 0.473 (359.22 %)
#  - Checking the test metrics for Salzburg (Austria) using 91 runs:
# NMAE: from 0.627 to 0.386 (-38.44 %)
# BIAS: from -9.38 to -1.706 (-81.81 %)
# RMSE: from 15.391 to 10.121 (-34.24 %)
# De-Biased NMAE: from 0.433 to 0.329 (-24.02 %)
# Pearson Correlation: from 0.145 to 0.43 (196.55 %)
#
#
#  - Checking the train metrics for Adelaide (Australia) using 452 runs:
# NMAE: from 0.657 to 0.539 (-17.96 %)
# BIAS: from -7.199 to -2.705 (-62.43 %)
# RMSE: from 13.959 to 11.121 (-20.33 %)
# De-Biased NMAE: from 0.557 to 0.474 (-14.9 %)
# Pearson Correlation: from 0.086 to 0.376 (337.21 %)
#  - Checking the test metrics for Adelaide (Australia) using 113 runs:
# NMAE: from 0.682 to 0.587 (-13.93 %)
# BIAS: from -6.649 to -2.165 (-67.44 %)
# RMSE: from 13.641 to 11.225 (-17.71 %)
# De-Biased NMAE: from 0.567 to 0.496 (-12.52 %)
# Pearson Correlation: from 0.104 to 0.365 (250.96 %)
#
#
#  - Checking the train metrics for Sydney (Australia) using 623 runs:
# NMAE: from 1.919 to 1.332 (-30.59 %)
# BIAS: from 9.132 to 3.312 (-63.73 %)
# RMSE: from 19.715 to 15.741 (-20.16 %)
# De-Biased NMAE: from 1.168 to 0.901 (-22.86 %)
# Pearson Correlation: from 0.343 to 0.43 (25.36 %)
#  - Checking the test metrics for Sydney (Australia) using 156 runs:
# NMAE: from 2.07 to 1.473 (-28.84 %)
# BIAS: from 10.203 to 4.353 (-57.34 %)
# RMSE: from 18.473 to 14.641 (-20.74 %)
# De-Biased NMAE: from 1.258 to 0.972 (-22.73 %)
# Pearson Correlation: from 0.342 to 0.414 (21.05 %)
#
#
#  - Checking the train metrics for Melbourne (Australia) using 535 runs:
# NMAE: from 0.515 to 0.525 (1.94 %)
# BIAS: from -0.111 to 1.49 (1242.34 %)
# RMSE: from 9.523 to 8.927 (-6.26 %)
# De-Biased NMAE: from 0.442 to 0.418 (-5.43 %)
# Pearson Correlation: from 0.331 to 0.465 (40.48 %)
#  - Checking the test metrics for Melbourne (Australia) using 134 runs:
# NMAE: from 0.528 to 0.559 (5.87 %)
# BIAS: from -0.103 to 1.467 (1324.27 %)
# RMSE: from 9.775 to 9.435 (-3.48 %)
# De-Biased NMAE: from 0.469 to 0.444 (-5.33 %)
# Pearson Correlation: from 0.352 to 0.475 (34.94 %)
#
#
#  - Checking the train metrics for Canberra (Australia) using 119 runs:
# NMAE: from 0.68 to 0.719 (5.74 %)
# BIAS: from -1.3 to -0.267 (-79.46 %)
# RMSE: from 6.839 to 7.043 (2.98 %)
# De-Biased NMAE: from 0.53 to 0.636 (20.0 %)
# Pearson Correlation: from 0.415 to 0.251 (-39.52 %)
#  - Checking the test metrics for Canberra (Australia) using 30 runs:
# NMAE: from 0.653 to 0.77 (17.92 %)
# BIAS: from -0.961 to -0.659 (-31.43 %)
# RMSE: from 6.355 to 6.965 (9.6 %)
# De-Biased NMAE: from 0.526 to 0.597 (13.5 %)
# Pearson Correlation: from 0.364 to 0.371 (1.92 %)
#
#
#  - Checking the train metrics for Dhaka (Bangladesh) using 76 runs:
# NMAE: from 5.758 to 1.935 (-66.39 %)
# BIAS: from 69.035 to 20.547 (-70.24 %)
# RMSE: from 77.212 to 27.203 (-64.77 %)
# De-Biased NMAE: from 2.473 to 1.014 (-59.0 %)
# Pearson Correlation: from 0.633 to 0.398 (-37.12 %)
#  - Checking the test metrics for Dhaka (Bangladesh) using 20 runs:
# NMAE: from 5.065 to 1.974 (-61.03 %)
# BIAS: from 75.127 to 26.818 (-64.3 %)
# RMSE: from 83.084 to 33.025 (-60.25 %)
# De-Biased NMAE: from 1.962 to 0.846 (-56.88 %)
# Pearson Correlation: from 0.647 to 0.363 (-43.89 %)
#
#
#  - Checking the train metrics for Brussels (Belgium) using 1 runs:
# NMAE: from 0.55 to 0.593 (7.82 %)
# BIAS: from 12.935 to 16.685 (28.99 %)
# RMSE: from 23.842 to 24.108 (1.12 %)
# De-Biased NMAE: from 0.582 to 0.502 (-13.75 %)
# Pearson Correlation: from -0.168 to 0.039 (123.21 %)
#  - Checking the test metrics for Brussels (Belgium) using 1 runs:
# NMAE: from 0.586 to 0.415 (-29.18 %)
# BIAS: from -2.435 to 3.118 (28.05 %)
# RMSE: from 15.064 to 12.25 (-18.68 %)
# De-Biased NMAE: from 0.526 to 0.429 (-18.44 %)
# Pearson Correlation: from 0.231 to 0.257 (11.26 %)
#
#
#  - Checking the train metrics for Sofia (Bulgaria) using 358 runs:
# NMAE: from 0.703 to 0.367 (-47.8 %)
# BIAS: from -16.357 to -2.026 (-87.61 %)
# RMSE: from 19.675 to 10.659 (-45.82 %)
# De-Biased NMAE: from 0.355 to 0.296 (-16.62 %)
# Pearson Correlation: from 0.173 to 0.518 (199.42 %)
#  - Checking the test metrics for Sofia (Bulgaria) using 90 runs:
# NMAE: from 0.707 to 0.409 (-42.15 %)
# BIAS: from -17.28 to -2.845 (-83.54 %)
# RMSE: from 20.711 to 11.87 (-42.69 %)
# De-Biased NMAE: from 0.352 to 0.3 (-14.77 %)
# Pearson Correlation: from 0.199 to 0.489 (145.73 %)
#
#
#  - Checking the train metrics for São Paulo (Brazil) using 116 runs:
# NMAE: from 1.0 to 0.364 (-63.6 %)
# BIAS: from -28.801 to -4.578 (-84.1 %)
# RMSE: from 30.36 to 12.664 (-58.29 %)
# De-Biased NMAE: from 0.273 to 0.268 (-1.83 %)
# Pearson Correlation: from -0.16 to 0.245 (253.12 %)
#  - Checking the test metrics for São Paulo (Brazil) using 29 runs:
# NMAE: from 1.0 to 0.394 (-60.6 %)
# BIAS: from -31.702 to -7.197 (-77.3 %)
# RMSE: from 33.494 to 15.084 (-54.97 %)
# De-Biased NMAE: from 0.273 to 0.279 (2.2 %)
# Pearson Correlation: from 0.082 to 0.035 (-57.32 %)
#
#
#  - Checking the train metrics for Montreal (Canada) using 339 runs:
# NMAE: from 0.76 to 0.616 (-18.95 %)
# BIAS: from -10.791 to -0.506 (-95.31 %)
# RMSE: from 13.181 to 8.753 (-33.59 %)
# De-Biased NMAE: from 0.412 to 0.403 (-2.18 %)
# Pearson Correlation: from -0.188 to 0.18 (195.74 %)
#  - Checking the test metrics for Montreal (Canada) using 85 runs:
# NMAE: from 0.756 to 0.593 (-21.56 %)
# BIAS: from -11.041 to -0.81 (-92.66 %)
# RMSE: from 13.584 to 9.41 (-30.73 %)
# De-Biased NMAE: from 0.405 to 0.4 (-1.23 %)
# Pearson Correlation: from -0.146 to 0.123 (184.25 %)
#
#
#  - Checking the train metrics for Vancouver (Canada) using 541 runs:
# NMAE: from 0.897 to 0.952 (6.13 %)
# BIAS: from -3.888 to 1.335 (-65.66 %)
# RMSE: from 11.817 to 10.671 (-9.7 %)
# De-Biased NMAE: from 0.681 to 0.632 (-7.2 %)
# Pearson Correlation: from -0.183 to -0.015 (91.8 %)
#  - Checking the test metrics for Vancouver (Canada) using 136 runs:
# NMAE: from 0.85 to 0.974 (14.59 %)
# BIAS: from -3.673 to 1.523 (-58.54 %)
# RMSE: from 11.581 to 11.042 (-4.65 %)
# De-Biased NMAE: from 0.696 to 0.667 (-4.17 %)
# Pearson Correlation: from -0.17 to -0.041 (75.88 %)
#
#
#  - Checking the train metrics for Zurich (Switzerland) using 455 runs:
# NMAE: from 0.605 to 0.5 (-17.36 %)
# BIAS: from -2.935 to 4.058 (38.26 %)
# RMSE: from 16.128 to 13.784 (-14.53 %)
# De-Biased NMAE: from 0.491 to 0.375 (-23.63 %)
# Pearson Correlation: from 0.222 to 0.44 (98.2 %)
#  - Checking the test metrics for Zurich (Switzerland) using 114 runs:
# NMAE: from 0.591 to 0.516 (-12.69 %)
# BIAS: from -2.545 to 4.407 (73.16 %)
# RMSE: from 15.926 to 13.983 (-12.2 %)
# De-Biased NMAE: from 0.484 to 0.377 (-22.11 %)
# Pearson Correlation: from 0.257 to 0.465 (80.93 %)
#
#
#  - Checking the train metrics for Geneva (Switzerland) using 683 runs:
# NMAE: from 0.591 to 0.562 (-4.91 %)
# BIAS: from -3.766 to 1.317 (-65.03 %)
# RMSE: from 10.816 to 9.23 (-14.66 %)
# De-Biased NMAE: from 0.469 to 0.409 (-12.79 %)
# Pearson Correlation: from 0.314 to 0.454 (44.59 %)
#  - Checking the test metrics for Geneva (Switzerland) using 171 runs:
# NMAE: from 0.602 to 0.584 (-2.99 %)
# BIAS: from -3.265 to 1.772 (-45.73 %)
# RMSE: from 10.74 to 9.594 (-10.67 %)
# De-Biased NMAE: from 0.476 to 0.428 (-10.08 %)
# Pearson Correlation: from 0.347 to 0.471 (35.73 %)
#
#
#  - Checking the train metrics for Santiago (Chile) using 644 runs:
# NMAE: from 0.999 to 0.365 (-63.46 %)
# BIAS: from -33.982 to -3.661 (-89.23 %)
# RMSE: from 36.555 to 14.497 (-60.34 %)
# De-Biased NMAE: from 0.32 to 0.27 (-15.62 %)
# Pearson Correlation: from -0.338 to 0.562 (266.27 %)
#  - Checking the test metrics for Santiago (Chile) using 161 runs:
# NMAE: from 0.999 to 0.366 (-63.36 %)
# BIAS: from -33.472 to -2.872 (-91.42 %)
# RMSE: from 35.887 to 13.978 (-61.05 %)
# De-Biased NMAE: from 0.313 to 0.266 (-15.02 %)
# Pearson Correlation: from -0.351 to 0.556 (258.4 %)
#
#
#  - Checking the train metrics for Shanghai (China) using 916 runs:
# NMAE: from 1.732 to 0.694 (-59.93 %)
# BIAS: from 57.564 to 15.128 (-73.72 %)
# RMSE: from 62.915 to 28.451 (-54.78 %)
# De-Biased NMAE: from 0.597 to 0.479 (-19.77 %)
# Pearson Correlation: from 0.451 to 0.367 (-18.63 %)
#  - Checking the test metrics for Shanghai (China) using 230 runs:
# NMAE: from 1.717 to 0.741 (-56.84 %)
# BIAS: from 57.076 to 15.712 (-72.47 %)
# RMSE: from 62.555 to 29.466 (-52.9 %)
# De-Biased NMAE: from 0.604 to 0.482 (-20.2 %)
# Pearson Correlation: from 0.411 to 0.361 (-12.17 %)
#
#
#  - Checking the train metrics for Chongqing (China) using 902 runs:
# NMAE: from 0.78 to 0.466 (-40.26 %)
# BIAS: from 26.606 to 5.364 (-79.84 %)
# RMSE: from 39.672 to 26.434 (-33.37 %)
# De-Biased NMAE: from 0.438 to 0.365 (-16.67 %)
# Pearson Correlation: from 0.438 to 0.323 (-26.26 %)
#  - Checking the test metrics for Chongqing (China) using 226 runs:
# NMAE: from 0.808 to 0.524 (-35.15 %)
# BIAS: from 27.736 to 6.824 (-75.4 %)
# RMSE: from 40.269 to 28.828 (-28.41 %)
# De-Biased NMAE: from 0.459 to 0.394 (-14.16 %)
# Pearson Correlation: from 0.447 to 0.312 (-30.2 %)
#
#
#  - Checking the train metrics for Beijing (China) using 905 runs:
# NMAE: from 2.724 to 1.118 (-58.96 %)
# BIAS: from 81.736 to 25.149 (-69.23 %)
# RMSE: from 90.091 to 42.615 (-52.7 %)
# De-Biased NMAE: from 1.051 to 0.791 (-24.74 %)
# Pearson Correlation: from 0.354 to 0.374 (5.65 %)
#  - Checking the test metrics for Beijing (China) using 227 runs:
# NMAE: from 2.66 to 1.193 (-55.15 %)
# BIAS: from 80.352 to 24.064 (-70.05 %)
# RMSE: from 88.461 to 44.654 (-49.52 %)
# De-Biased NMAE: from 1.033 to 0.811 (-21.49 %)
# Pearson Correlation: from 0.363 to 0.363 (0.0 %)
#
#
#  - Checking the train metrics for Shenyang (China) using 912 runs:
# NMAE: from 1.004 to 0.577 (-42.53 %)
# BIAS: from 27.93 to 3.418 (-87.76 %)
# RMSE: from 38.307 to 22.955 (-40.08 %)
# De-Biased NMAE: from 0.629 to 0.464 (-26.23 %)
# Pearson Correlation: from 0.409 to 0.409 (0.0 %)
#  - Checking the test metrics for Shenyang (China) using 229 runs:
# NMAE: from 1.004 to 0.596 (-40.64 %)
# BIAS: from 27.564 to 2.257 (-91.81 %)
# RMSE: from 37.567 to 23.081 (-38.56 %)
# De-Biased NMAE: from 0.619 to 0.472 (-23.75 %)
# Pearson Correlation: from 0.445 to 0.42 (-5.62 %)
#
#
#  - Checking the train metrics for Bogotá (Colombia) using 104 runs:
# NMAE: from 0.995 to 0.327 (-67.14 %)
# BIAS: from -33.737 to -2.97 (-91.2 %)
# RMSE: from 35.389 to 12.965 (-63.36 %)
# De-Biased NMAE: from 0.254 to 0.242 (-4.72 %)
# Pearson Correlation: from -0.139 to 0.285 (305.04 %)
#  - Checking the test metrics for Bogotá (Colombia) using 26 runs:
# NMAE: from 0.996 to 0.327 (-67.17 %)
# BIAS: from -36.704 to -6.087 (-83.42 %)
# RMSE: from 38.336 to 14.534 (-62.09 %)
# De-Biased NMAE: from 0.242 to 0.231 (-4.55 %)
# Pearson Correlation: from -0.178 to 0.3 (268.54 %)
#
#
#  - Checking the train metrics for Prague (Czechia) using 548 runs:
# NMAE: from 0.459 to 0.353 (-23.09 %)
# BIAS: from -5.073 to 1.378 (-72.84 %)
# RMSE: from 14.337 to 11.463 (-20.05 %)
# De-Biased NMAE: from 0.332 to 0.278 (-16.27 %)
# Pearson Correlation: from 0.478 to 0.596 (24.69 %)
#  - Checking the test metrics for Prague (Czechia) using 137 runs:
# NMAE: from 0.452 to 0.358 (-20.8 %)
# BIAS: from -4.943 to 1.396 (-71.76 %)
# RMSE: from 13.786 to 11.365 (-17.56 %)
# De-Biased NMAE: from 0.331 to 0.289 (-12.69 %)
# Pearson Correlation: from 0.477 to 0.585 (22.64 %)
#
#
#  - Checking the train metrics for Copenhagen (Denmark) using 563 runs:
# NMAE: from 0.673 to 0.632 (-6.09 %)
# BIAS: from -10.633 to -0.609 (-94.27 %)
# RMSE: from 14.117 to 9.496 (-32.73 %)
# De-Biased NMAE: from 0.37 to 0.4 (8.11 %)
# Pearson Correlation: from 0.348 to 0.53 (52.3 %)
#  - Checking the test metrics for Copenhagen (Denmark) using 141 runs:
# NMAE: from 0.64 to 0.608 (-5.0 %)
# BIAS: from -10.361 to -0.329 (-96.82 %)
# RMSE: from 13.59 to 9.456 (-30.42 %)
# De-Biased NMAE: from 0.349 to 0.377 (8.02 %)
# Pearson Correlation: from 0.337 to 0.51 (51.34 %)
#
#
#  - Checking the train metrics for Madrid (Spain) using 263 runs:
# NMAE: from 0.932 to 0.451 (-51.61 %)
# BIAS: from -38.162 to -8.067 (-78.86 %)
# RMSE: from 40.777 to 20.744 (-49.13 %)
# De-Biased NMAE: from 0.306 to 0.3 (-1.96 %)
# Pearson Correlation: from 0.345 to 0.315 (-8.7 %)
#  - Checking the test metrics for Madrid (Spain) using 66 runs:
# NMAE: from 0.93 to 0.497 (-46.56 %)
# BIAS: from -36.814 to -7.621 (-79.3 %)
# RMSE: from 39.517 to 21.452 (-45.71 %)
# De-Biased NMAE: from 0.318 to 0.308 (-3.14 %)
# Pearson Correlation: from 0.332 to 0.345 (3.92 %)
#
#
#  - Checking the train metrics for Barcelona (Spain) using 291 runs:
# NMAE: from 0.571 to 0.408 (-28.55 %)
# BIAS: from -16.956 to -0.781 (-95.39 %)
# RMSE: from 22.18 to 15.226 (-31.35 %)
# De-Biased NMAE: from 0.302 to 0.29 (-3.97 %)
# Pearson Correlation: from 0.371 to 0.413 (11.32 %)
#  - Checking the test metrics for Barcelona (Spain) using 73 runs:
# NMAE: from 0.584 to 0.399 (-31.68 %)
# BIAS: from -19.066 to -2.88 (-84.89 %)
# RMSE: from 23.829 to 15.948 (-33.07 %)
# De-Biased NMAE: from 0.301 to 0.286 (-4.98 %)
# Pearson Correlation: from 0.446 to 0.485 (8.74 %)
#
#
#  - Checking the train metrics for Helsinki (Finland) using 818 runs:
# NMAE: from 0.556 to 0.505 (-9.17 %)
# BIAS: from -9.078 to 0.018 (-99.8 %)
# RMSE: from 14.207 to 11.093 (-21.92 %)
# De-Biased NMAE: from 0.397 to 0.361 (-9.07 %)
# Pearson Correlation: from 0.395 to 0.558 (41.27 %)
#  - Checking the test metrics for Helsinki (Finland) using 205 runs:
# NMAE: from 0.575 to 0.555 (-3.48 %)
# BIAS: from -9.386 to -0.383 (-95.92 %)
# RMSE: from 14.697 to 11.855 (-19.34 %)
# De-Biased NMAE: from 0.406 to 0.383 (-5.67 %)
# Pearson Correlation: from 0.389 to 0.52 (33.68 %)
#
#
#  - Checking the train metrics for Paris (France) using 553 runs:
# NMAE: from 0.5 to 0.381 (-23.8 %)
# BIAS: from -10.278 to -0.114 (-98.89 %)
# RMSE: from 19.23 to 14.498 (-24.61 %)
# De-Biased NMAE: from 0.354 to 0.294 (-16.95 %)
# Pearson Correlation: from 0.354 to 0.509 (43.79 %)
#  - Checking the test metrics for Paris (France) using 139 runs:
# NMAE: from 0.506 to 0.419 (-17.19 %)
# BIAS: from -9.015 to 1.06 (-88.24 %)
# RMSE: from 18.952 to 15.006 (-20.82 %)
# De-Biased NMAE: from 0.377 to 0.321 (-14.85 %)
# Pearson Correlation: from 0.356 to 0.491 (37.92 %)
#
#
#  - Checking the train metrics for London (United Kingdom) using 664 runs:
# NMAE: from 0.414 to 0.367 (-11.35 %)
# BIAS: from -6.519 to 2.716 (-58.34 %)
# RMSE: from 15.123 to 12.741 (-15.75 %)
# De-Biased NMAE: from 0.312 to 0.271 (-13.14 %)
# Pearson Correlation: from 0.477 to 0.575 (20.55 %)
#  - Checking the test metrics for London (United Kingdom) using 167 runs:
# NMAE: from 0.404 to 0.348 (-13.86 %)
# BIAS: from -7.011 to 2.168 (-69.08 %)
# RMSE: from 14.97 to 12.416 (-17.06 %)
# De-Biased NMAE: from 0.299 to 0.264 (-11.71 %)
# Pearson Correlation: from 0.499 to 0.588 (17.84 %)
#
#
#  - Checking the train metrics for Glasgow (United Kingdom) using 578 runs:
# NMAE: from 0.872 to 0.647 (-25.8 %)
# BIAS: from -20.569 to -3.806 (-81.5 %)
# RMSE: from 23.424 to 13.699 (-41.52 %)
# De-Biased NMAE: from 0.388 to 0.372 (-4.12 %)
# Pearson Correlation: from 0.041 to 0.417 (917.07 %)
#  - Checking the test metrics for Glasgow (United Kingdom) using 145 runs:
# NMAE: from 0.871 to 0.622 (-28.59 %)
# BIAS: from -19.721 to -3.202 (-83.76 %)
# RMSE: from 22.308 to 13.086 (-41.34 %)
# De-Biased NMAE: from 0.376 to 0.362 (-3.72 %)
# Pearson Correlation: from 0.066 to 0.396 (500.0 %)
#
#
#  - Checking the train metrics for Belfast (United Kingdom) using 609 runs:
# NMAE: from 0.787 to 0.607 (-22.87 %)
# BIAS: from -16.309 to -5.925 (-63.67 %)
# RMSE: from 20.984 to 15.004 (-28.5 %)
# De-Biased NMAE: from 0.459 to 0.42 (-8.5 %)
# Pearson Correlation: from 0.084 to 0.347 (313.1 %)
#  - Checking the test metrics for Belfast (United Kingdom) using 153 runs:
# NMAE: from 0.788 to 0.663 (-15.86 %)
# BIAS: from -16.222 to -6.078 (-62.53 %)
# RMSE: from 20.541 to 15.054 (-26.71 %)
# De-Biased NMAE: from 0.445 to 0.421 (-5.39 %)
# Pearson Correlation: from 0.036 to 0.315 (775.0 %)
#
#
#  - Checking the train metrics for Cayenne (French Guiana) using 498 runs:
# NMAE: from 0.944 to 1.061 (12.39 %)
# BIAS: from -2.62 to 0.425 (-83.78 %)
# RMSE: from 3.692 to 2.978 (-19.34 %)
# De-Biased NMAE: from 0.673 to 0.743 (10.4 %)
# Pearson Correlation: from -0.059 to 0.327 (654.24 %)
#  - Checking the test metrics for Cayenne (French Guiana) using 125 runs:
# NMAE: from 0.953 to 1.078 (13.12 %)
# BIAS: from -2.576 to 0.557 (-78.38 %)
# RMSE: from 3.619 to 2.891 (-20.12 %)
# De-Biased NMAE: from 0.677 to 0.754 (11.37 %)
# Pearson Correlation: from -0.069 to 0.321 (565.22 %)
#
#
#  - Checking the train metrics for Athens (Greece) using 376 runs:
# NMAE: from 0.692 to 0.276 (-60.12 %)
# BIAS: from -29.682 to -2.102 (-92.92 %)
# RMSE: from 33.922 to 14.383 (-57.6 %)
# De-Biased NMAE: from 0.288 to 0.218 (-24.31 %)
# Pearson Correlation: from 0.088 to 0.44 (400.0 %)
#  - Checking the test metrics for Athens (Greece) using 94 runs:
# NMAE: from 0.695 to 0.289 (-58.42 %)
# BIAS: from -29.085 to -1.396 (-95.2 %)
# RMSE: from 33.461 to 14.515 (-56.62 %)
# De-Biased NMAE: from 0.297 to 0.217 (-26.94 %)
# Pearson Correlation: from 0.115 to 0.461 (300.87 %)
#
#
#  - Checking the train metrics for Hong Kong (Hong Kong) using 477 runs:
# NMAE: from 0.449 to 0.392 (-12.69 %)
# BIAS: from 17.634 to 12.956 (-26.53 %)
# RMSE: from 37.232 to 32.86 (-11.74 %)
# De-Biased NMAE: from 0.323 to 0.29 (-10.22 %)
# Pearson Correlation: from 0.643 to 0.664 (3.27 %)
#  - Checking the test metrics for Hong Kong (Hong Kong) using 120 runs:
# NMAE: from 0.441 to 0.398 (-9.75 %)
# BIAS: from 18.466 to 14.008 (-24.14 %)
# RMSE: from 36.194 to 32.64 (-9.82 %)
# De-Biased NMAE: from 0.311 to 0.279 (-10.29 %)
# Pearson Correlation: from 0.637 to 0.667 (4.71 %)
#
#
#  - Checking the train metrics for Zagreb (Croatia) using 571 runs:
# NMAE: from 0.757 to 0.672 (-11.23 %)
# BIAS: from -9.541 to -2.133 (-77.64 %)
# RMSE: from 19.737 to 15.741 (-20.25 %)
# De-Biased NMAE: from 0.508 to 0.468 (-7.87 %)
# Pearson Correlation: from 0.35 to 0.47 (34.29 %)
#  - Checking the test metrics for Zagreb (Croatia) using 143 runs:
# NMAE: from 0.744 to 0.663 (-10.89 %)
# BIAS: from -9.789 to -2.532 (-74.13 %)
# RMSE: from 19.898 to 15.875 (-20.22 %)
# De-Biased NMAE: from 0.484 to 0.441 (-8.88 %)
# Pearson Correlation: from 0.357 to 0.476 (33.33 %)
#
#
#  - Checking the train metrics for Budapest (Hungary) using 529 runs:
# NMAE: from 0.583 to 0.341 (-41.51 %)
# BIAS: from -17.438 to -2.628 (-84.93 %)
# RMSE: from 21.987 to 13.381 (-39.14 %)
# De-Biased NMAE: from 0.298 to 0.271 (-9.06 %)
# Pearson Correlation: from 0.427 to 0.543 (27.17 %)
#  - Checking the test metrics for Budapest (Hungary) using 133 runs:
# NMAE: from 0.581 to 0.343 (-40.96 %)
# BIAS: from -17.618 to -2.77 (-84.28 %)
# RMSE: from 21.977 to 13.375 (-39.14 %)
# De-Biased NMAE: from 0.3 to 0.277 (-7.67 %)
# Pearson Correlation: from 0.447 to 0.532 (19.02 %)
#
#
#  - Checking the train metrics for Dublin (Ireland) using 565 runs:
# NMAE: from 0.705 to 0.946 (34.18 %)
# BIAS: from -4.554 to 4.171 (-8.41 %)
# RMSE: from 11.334 to 11.207 (-1.12 %)
# De-Biased NMAE: from 0.569 to 0.521 (-8.44 %)
# Pearson Correlation: from 0.229 to 0.365 (59.39 %)
#  - Checking the test metrics for Dublin (Ireland) using 142 runs:
# NMAE: from 0.717 to 1.142 (59.27 %)
# BIAS: from -4.301 to 4.876 (13.37 %)
# RMSE: from 11.191 to 11.876 (6.12 %)
# De-Biased NMAE: from 0.579 to 0.567 (-2.07 %)
# Pearson Correlation: from 0.203 to 0.32 (57.64 %)
#
#
#  - Checking the train metrics for New Delhi (India) using 540 runs:
# NMAE: from 1.31 to 0.717 (-45.27 %)
# BIAS: from 36.598 to 9.631 (-73.68 %)
# RMSE: from 50.801 to 31.272 (-38.44 %)
# De-Biased NMAE: from 0.811 to 0.578 (-28.73 %)
# Pearson Correlation: from 0.367 to 0.321 (-12.53 %)
#  - Checking the test metrics for New Delhi (India) using 135 runs:
# NMAE: from 1.48 to 0.838 (-43.38 %)
# BIAS: from 42.634 to 15.768 (-63.02 %)
# RMSE: from 55.904 to 35.023 (-37.35 %)
# De-Biased NMAE: from 0.883 to 0.634 (-28.2 %)
# Pearson Correlation: from 0.348 to 0.271 (-22.13 %)
#
#
#  - Checking the train metrics for Kolkata (India) using 617 runs:
# NMAE: from 1.016 to 0.597 (-41.24 %)
# BIAS: from 26.408 to 5.762 (-78.18 %)
# RMSE: from 40.449 to 24.167 (-40.25 %)
# De-Biased NMAE: from 0.733 to 0.476 (-35.06 %)
# Pearson Correlation: from 0.586 to 0.466 (-20.48 %)
#  - Checking the test metrics for Kolkata (India) using 155 runs:
# NMAE: from 1.075 to 0.705 (-34.42 %)
# BIAS: from 27.182 to 5.685 (-79.09 %)
# RMSE: from 40.891 to 26.642 (-34.85 %)
# De-Biased NMAE: from 0.761 to 0.513 (-32.59 %)
# Pearson Correlation: from 0.579 to 0.436 (-24.7 %)
